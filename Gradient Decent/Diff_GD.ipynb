# %%
import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
import zipfile
zip = zipfile.ZipFile('/content/archive(7).zip')
zip.extractall()
zip.close()

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
if 'User ID' in df.columns:
  df.drop(['User ID'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3583891308.py in <cell line: 0>()
# ----> 1 df = df.drop(['User ID'],axis=1,inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['User ID'] not found in axis"

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         1   19            19000          0
# 1         1   35            20000          0
# 2         0   26            43000          0
# 3         0   27            57000          0
# 4         1   19            76000          0
# ..      ...  ...              ...        ...
# 395       0   46            41000          1
# 396       1   51            23000          1
# 397       0   50            20000          1
# 398       1   36            33000          0
# 399       0   49            36000          1
#
# [400 rows x 4 columns]

# %%
X = df.drop(['Purchased'], axis=1)
y = df['Purchased']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (400, 3)

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_dim = 3))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy',metrics=['Accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 32)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 673 (2.63 KB)
#  Trainable params: 673 (2.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Batch GD

# %%
import time
start_time = time.time()
model.fit(X_scaled, y, batch_size=1, epochs=30, verbose=1, validation_split=0.2)
print(time.time()-start_time)
# Out:
# Epoch 1/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9050 - loss: 0.2498 - val_Accuracy: 0.9125 - val_loss: 0.2696
# Epoch 2/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8977 - loss: 0.2221 - val_Accuracy: 0.9500 - val_loss: 0.2554
# Epoch 3/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9172 - loss: 0.2058 - val_Accuracy: 0.9375 - val_loss: 0.2820
# Epoch 4/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8957 - loss: 0.2173 - val_Accuracy: 0.9250 - val_loss: 0.2746
# Epoch 5/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9324 - loss: 0.1764 - val_Accuracy: 0.9125 - val_loss: 0.2793
# Epoch 6/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9349 - loss: 0.1771 - val_Accuracy: 0.9125 - val_loss: 0.2976
# Epoch 7/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9172 - loss: 0.1888 - val_Accuracy: 0.9250 - val_loss: 0.3050
# Epoch 8/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9198 - loss: 0.1916 - val_Accuracy: 0.8500 - val_loss: 0.3479
# Epoch 9/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8833 - loss: 0.2337 - val_Accuracy: 0.8500 - val_loss: 0.3653
# Epoch 10/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8997 - loss: 0.2062 - val_Accuracy: 0.9125 - val_loss: 0.2645
# Epoch 11/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9097 - loss: 0.2078 - val_Accuracy: 0.9625 - val_loss: 0.2763
# Epoch 12/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9228 - loss: 0.1679 - val_Accuracy: 0.9375 - val_loss: 0.2728
# Epoch 13/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9017 - loss: 0.1998 - val_Accuracy: 0.9500 - val_loss: 0.2254
# Epoch 14/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9051 - loss: 0.2064 - val_Accuracy: 0.8500 - val_loss: 0.3562
# Epoch 15/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9081 - loss: 0.1724 - val_Accuracy: 0.9125 - val_loss: 0.3036
# Epoch 16/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9043 - loss: 0.2173 - val_Accuracy: 0.9250 - val_loss: 0.2724
# Epoch 17/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9352 - loss: 0.1737 - val_Accuracy: 0.8750 - val_loss: 0.3022
# Epoch 18/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9268 - loss: 0.2044 - val_Accuracy: 0.9250 - val_loss: 0.3331
# Epoch 19/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9136 - loss: 0.2126 - val_Accuracy: 0.9125 - val_loss: 0.3057
# Epoch 20/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9265 - loss: 0.1807 - val_Accuracy: 0.9250 - val_loss: 0.2971
# Epoch 21/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8969 - loss: 0.2176 - val_Accuracy: 0.9250 - val_loss: 0.2558
# Epoch 22/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9157 - loss: 0.1914 - val_Accuracy: 0.9250 - val_loss: 0.2689
# Epoch 23/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8853 - loss: 0.2195 - val_Accuracy: 0.8750 - val_loss: 0.3653
# Epoch 24/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9283 - loss: 0.1402 - val_Accuracy: 0.9375 - val_loss: 0.2651
# Epoch 25/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9271 - loss: 0.1766 - val_Accuracy: 0.8750 - val_loss: 0.2866
# Epoch 26/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8765 - loss: 0.2042 - val_Accuracy: 0.9000 - val_loss: 0.2930
# Epoch 27/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9272 - loss: 0.1607 - val_Accuracy: 0.8875 - val_loss: 0.3338
# Epoch 28/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9004 - loss: 0.2125 - val_Accuracy: 0.9625 - val_loss: 0.1987
# Epoch 29/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.8878 - loss: 0.1939 - val_Accuracy: 0.9875 - val_loss: 0.2711
# Epoch 30/30
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.9083 - loss: 0.2020 - val_Accuracy: 0.9625 - val_loss: 0.2844
# 22.60810351371765

# %% [markdown]
# ## Stochastic GD

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy',metrics=['Accuracy'])
start_time = time.time()
model.fit(X_scaled, y, batch_size=320, epochs=30, validation_split=0.2)
print(time.time()-start_time)
# Out:
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - Accuracy: 0.9125 - loss: 0.1883 - val_Accuracy: 0.9875 - val_loss: 0.2738
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - Accuracy: 0.9156 - loss: 0.1828 - val_Accuracy: 0.9875 - val_loss: 0.2627
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - Accuracy: 0.9094 - loss: 0.1785 - val_Accuracy: 0.9875 - val_loss: 0.2536
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - Accuracy: 0.9094 - loss: 0.1757 - val_Accuracy: 0.9875 - val_loss: 0.2463
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - Accuracy: 0.9094 - loss: 0.1739 - val_Accuracy: 0.9875 - val_loss: 0.2399
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - Accuracy: 0.9125 - loss: 0.1729 - val_Accuracy: 0.9875 - val_loss: 0.2343
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - Accuracy: 0.9094 - loss: 0.1721 - val_Accuracy: 0.9875 - val_loss: 0.2299
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - Accuracy: 0.9125 - loss: 0.1711 - val_Accuracy: 0.9875 - val_loss: 0.2269
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - Accuracy: 0.9125 - loss: 0.1700 - val_Accuracy: 0.9875 - val_loss: 0.2252
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - Accuracy: 0.9156 - loss: 0.1690 - val_Accuracy: 0.9750 - val_loss: 0.2238
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - Accuracy: 0.9156 - loss: 0.1679 - val_Accuracy: 0.9750 - val_loss: 0.2224
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - Accuracy: 0.9156 - loss: 0.1668 - val_Accuracy: 0.9750 - val_loss: 0.2219
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - Accuracy: 0.9156 - loss: 0.1657 - val_Accuracy: 0.9750 - val_loss: 0.2220
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - Accuracy: 0.9187 - loss: 0.1649 - val_Accuracy: 0.9750 - val_loss: 0.2230
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - Accuracy: 0.9219 - loss: 0.1640 - val_Accuracy: 0.9750 - val_loss: 0.2254
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - Accuracy: 0.9187 - loss: 0.1629 - val_Accuracy: 0.9625 - val_loss: 0.2288
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - Accuracy: 0.9187 - loss: 0.1618 - val_Accuracy: 0.9625 - val_loss: 0.2323
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - Accuracy: 0.9187 - loss: 0.1610 - val_Accuracy: 0.9500 - val_loss: 0.2348
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - Accuracy: 0.9219 - loss: 0.1600 - val_Accuracy: 0.9375 - val_loss: 0.2365
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - Accuracy: 0.9219 - loss: 0.1591 - val_Accuracy: 0.9250 - val_loss: 0.2378
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - Accuracy: 0.9219 - loss: 0.1583 - val_Accuracy: 0.9125 - val_loss: 0.2387
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - Accuracy: 0.9187 - loss: 0.1574 - val_Accuracy: 0.9125 - val_loss: 0.2392
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - Accuracy: 0.9187 - loss: 0.1566 - val_Accuracy: 0.9125 - val_loss: 0.2395
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - Accuracy: 0.9219 - loss: 0.1560 - val_Accuracy: 0.9125 - val_loss: 0.2392
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - Accuracy: 0.9219 - loss: 0.1554 - val_Accuracy: 0.9125 - val_loss: 0.2390
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - Accuracy: 0.9219 - loss: 0.1548 - val_Accuracy: 0.9125 - val_loss: 0.2391
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - Accuracy: 0.9250 - loss: 0.1543 - val_Accuracy: 0.9125 - val_loss: 0.2389
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - Accuracy: 0.9250 - loss: 0.1538 - val_Accuracy: 0.9125 - val_loss: 0.2387
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - Accuracy: 0.9250 - loss: 0.1531 - val_Accuracy: 0.9125 - val_loss: 0.2388
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - Accuracy: 0.9250 - loss: 0.1524 - val_Accuracy: 0.9125 - val_loss: 0.2390
# 5.330726623535156

# %% [markdown]
# ## Mini-Batch GD

# %%
start_time = time.time()
model.fit(X_scaled, y, batch_size = 20,epochs=30,validation_split=0.2)
print(time.time()-start_time)
# Out:
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - Accuracy: 0.9440 - loss: 0.1180 - val_Accuracy: 0.8875 - val_loss: 0.2840
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9365 - loss: 0.1362 - val_Accuracy: 0.9500 - val_loss: 0.2490
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9380 - loss: 0.1213 - val_Accuracy: 0.9125 - val_loss: 0.2700
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9236 - loss: 0.1490 - val_Accuracy: 0.9250 - val_loss: 0.2710
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9485 - loss: 0.1252 - val_Accuracy: 0.9125 - val_loss: 0.2637
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9291 - loss: 0.1372 - val_Accuracy: 0.9250 - val_loss: 0.2744
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9254 - loss: 0.1350 - val_Accuracy: 0.9250 - val_loss: 0.2701
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9141 - loss: 0.1481 - val_Accuracy: 0.9250 - val_loss: 0.2841
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9233 - loss: 0.1274 - val_Accuracy: 0.9500 - val_loss: 0.2658
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9290 - loss: 0.1444 - val_Accuracy: 0.9000 - val_loss: 0.2852
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9343 - loss: 0.1330 - val_Accuracy: 0.9250 - val_loss: 0.2742
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9431 - loss: 0.1232 - val_Accuracy: 0.9250 - val_loss: 0.2622
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9364 - loss: 0.1220 - val_Accuracy: 0.9250 - val_loss: 0.2768
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9353 - loss: 0.1271 - val_Accuracy: 0.9375 - val_loss: 0.2650
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9542 - loss: 0.1006 - val_Accuracy: 0.9125 - val_loss: 0.2836
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9500 - loss: 0.1124 - val_Accuracy: 0.9125 - val_loss: 0.2618
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9346 - loss: 0.1204 - val_Accuracy: 0.9125 - val_loss: 0.2807
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9483 - loss: 0.1100 - val_Accuracy: 0.8875 - val_loss: 0.3138
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9374 - loss: 0.1402 - val_Accuracy: 0.9375 - val_loss: 0.2649
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9325 - loss: 0.1272 - val_Accuracy: 0.9000 - val_loss: 0.2811
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9184 - loss: 0.1469 - val_Accuracy: 0.9250 - val_loss: 0.2834
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9383 - loss: 0.1179 - val_Accuracy: 0.9000 - val_loss: 0.2921
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - Accuracy: 0.9432 - loss: 0.1294 - val_Accuracy: 0.9000 - val_loss: 0.2739
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9182 - loss: 0.1414 - val_Accuracy: 0.8750 - val_loss: 0.3240
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9570 - loss: 0.1150 - val_Accuracy: 0.9125 - val_loss: 0.2553
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9385 - loss: 0.1342 - val_Accuracy: 0.9000 - val_loss: 0.3048
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9231 - loss: 0.1401 - val_Accuracy: 0.8875 - val_loss: 0.3130
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9491 - loss: 0.1111 - val_Accuracy: 0.9000 - val_loss: 0.2988
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9178 - loss: 0.1380 - val_Accuracy: 0.9000 - val_loss: 0.3076
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Accuracy: 0.9394 - loss: 0.1343 - val_Accuracy: 0.9125 - val_loss: 0.2817
# 3.6110165119171143
